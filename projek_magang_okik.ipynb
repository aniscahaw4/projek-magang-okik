# %% [markdown]
# <a href="https://colab.research.google.com/github/aniscahaw4/projek-magang-okik/blob/main/projek_magang_okik.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# index.html

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Mie Lampung Pak Di</title>
#
#     <!-- Fonts -->
#     <link rel="preconnect" href="https://fonts.googleapis.com" />
#     <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin />
#     <link
#       href="https://fonts.googleapis.com/css2?family=Poppins:ital,wght@0,100;0,300;0,400;0,700;1,700&display=swap"
#       rel="stylesheet"
#     />
#
#     <!-- Feather Icons -->
#     <script src="https://unpkg.com/feather-icons"></script>
#
#     <!-- My Style -->
#
#     <link rel="stylesheet" href="css/style.css" />
#   </head>
#
#   <body>
#     <!-- Navbar start -->
#     <nav class="navbar">
#       <a href="#" class="navbar-logo">Mie<span>Lampung</span>PakDi.</a>
#
#       <div class="navbar-nav">
#         <a href="#home">Home</a>
#         <a href="#about">Tentang Kami</a>
#         <a href="#menu">Menu</a>
#         <a href="#contact">Kontak</a>
#       </div>
#
#       <div class="navbar-extra">
#         <a href="#" id="search"><i data-feather="search"></i></a>
#         <a href="#" id="shopping-cart"><i data-feather="shopping-cart"></i></a>
#         <a href="#" id="hamburger-menu"><i data-feather="menu"></i></a>
#       </div>
#     </nav>
#     <!-- Navbar end -->
#
#     <!-- Hero Section start -->
#     <section class="hero" id="home">
#       <main class="content">
#         <h1>Mari Makan Di<span>MieLampungPakDi</span></h1>
#         <p>
#           CHINNESE FOOD
#         </p>
#         <a href="#" class="cta">Beli Sekarang</a>
#       </main>
#     </section>
#     <!-- Hero Section end -->
#
#     <!-- About Section start -->
#     <section id="about" class="about">
#       <h2><span>Tentang</span> Kami</h2>
#
#       <div class="row">
#         <div class="about-img">
#           <img src="img/seluruhmasakan.jpg" alt="Tentang Kami" />
#         </div>
#         <div class="content">
#           <h3>Kenapa Harus Makan Di Tempat Kami?</h3>
#           <p>
#             Disini menyajikan makanan yang setara dengan rasa makanan di restorant bintang lima
#           </p>
#           <p>
#            Dengan harga yang lebih murah dibanding dengan restorant bintang lima
#           </p>
#
#     </section>
#     <!-- About Section end -->
#
#     <!-- Menu Section start -->
#     <section id="menu" class="menu">
#       <h2><span>Menu</span> Kami</h2>
#       <p>
#    Siilahkan Dipilih
#       </p>
#
#       <div class="row">
#         <div class="menu-card">
#             <img src="img/Nasi goreng.jpg" alt="Nasi Goreng" class="menu-card-img">
#             <h3 class="menu-card-title">- Nasi Goreng -</h3>
#             <p class="menu-card-price">IDR 17K</p>
#         </div>
#         <div class="menu-card">
#             <img src="img/capjay.jpg" alt="CapJay" class="menu-card-img">
#             <h3 class="menu-card-title">- CapJay -</h3>
#             <p class="menu-card-price">IDR 20K</p>
#         </div>
#         <div class="menu-card">
#             <img src="img/Mie-Lampung.jpg" alt="Mie Lampung" class="menu-card-img">
#             <h3 class="menu-card-title">- Mie Lampung -</h3>
#             <p class="menu-card-price">IDR 25K</p>
#         </div>
#         <div class="menu-card">
#             <img src="img/kwetiau.jpg" alt="Kwetiaw" class="menu-card-img">
#             <h3 class="menu-card-title">- Kwetiaw -</h3>
#             <p class="menu-card-price">IDR 25k</p>
#         </div>
#         <div class="menu-card">
#             <img src="img/guramie.jpg" alt="Aneka Masakan IkanGuramie & IkanKakap" class="menu-card-img">
#             <h3 class="menu-card-title">- Aneka Masakan IkanGuramie & IkanKakap -</h3>
#             <p class="menu-card-price">IDR Menyesuaikan</p>
#         </div>
#         <div class="menu-card">
#             <img src="img/cumi.jpg" alt="Aneka Masakan Cumi" class="menu-card-img">
#             <h3 class="menu-card-title">- Aneka Masakan Cumi -</h3>
#             <p class="menu-card-price">IDR Menyesuaikan</p>
#         </div>
#         </div>
#   </div>
#     </section>
#     <!-- Menu Section end -->
#
#     <!-- Contact section start -->
# <section id="contact" class="contact">
#     <h2><span>Kontak</span> Kami</h2>
#     <p>
#     Lorem ipsum dolor sit amet consectetur adipisicing elit. Accusantium, facere.
#     </p>
#
#     <div class="row">
#       <iframe src="https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d126715.79465803024!2d110.4170652!3d-7.0247298!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x2e708b4d3f0d024d%3A0x1e0432b9da5cb9f2!2sKota%20Semarang%2C%20Jawa%20Tengah!5e0!3m2!1sid!2sid!4v1706494105589!5m2!1sid!2sid" allowfullscreen="" loading="lazy" referrerpolicy="no-referrer-when-downgrade" class="map"></iframe>
#
# <form action="">
#   <div class="input-group">
#     <i data-feather="user"></i>
#     <input type="text"
#     placeholder="Pakdi">
#   </div>
#   <div class="input-group">
#     <i data-feather="mail"></i>
#     <input type="text"
#     placeholder="Saputraakbar241002@gmail.com">
#   </div>
#   <div class="input-group">
#     <i data-feather="phone"></i>
#     <input type="text"
#     placeholder="08895739280">
#   </div>
#   <button type="submit"
#   class="btn">kirim pesan</button>
# </form>
#     </div>
# </section>
#
#     <!-- Contact section end -->
#
#     <!-- Footer start -->
#     <footer>
#       <div class="socials">
#         <a href="#"><i data-feather="instagram"></i></a>
#         <a href="#"><i data-feather="twitter"></i></a>
#         <a href="#"><i data-feather="facebook"></i></a>
#       </div>
#
#       <div class="links">
#         <a href="#home">Home</a>
#         <a href="#about">Tentang Kami</a>
#         <a href="#menu">Menu</a>
#         <a href="#contact">Kontak</a>
#     </div>
#
#     <div class="credit">
#       <p>Created by <a href="">Pak Di</a>. | &copy; 2024</p>
#       </div>
#     </footer>
#     <!-- Footer end -->
#
#     <!-- Feather Icons -->
#     <script>
#       feather.replace();
#     </script>
#
#     <!-- My Javascript -->
#     <script src="js/script.js"></script>
#   </body>
# </html>

# %% [markdown]
# script.js

# %% [markdown]
# // Toggle class active
# const navbarNav = document.querySelector(".navbar-nav");
# // ketika hamburger menu di klik
# document.querySelector("#hamburger-menu").onclick = () => {
#   navbarNav.classList.toggle("active");
# };
#
# //klik di luar slidebar untuk menghilangkan nav
# const hamburger = document.querySelector('#hamburger-menu');
#
# document.addEventListener('click', function(e) {
#     if(!hamburger.contains(e.target)&& !navbarNav.contains(e.target)) {
#         navbarNav.classList.remove('active');
#     }
# });
